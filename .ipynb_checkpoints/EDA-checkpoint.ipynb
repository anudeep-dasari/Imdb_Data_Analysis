# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = None
df = pd.read_csv('cleaned_imdb_data.csv', encoding = 'ISO-8859-1')
df.head()
# Out:
#                                         Title  Release Certificate  Runtime  \
# 0  Star Wars: Episode VII - The Force Awakens     2015           U      138
# 1                           Avengers: Endgame     2019          UA      181
# 2                                      Avatar     2009          UA      162
# 3                               Black Panther     2018          UA      134
# 4                      Avengers: Infinity War     2018          UA      149
#
#    Rating  Metascore                                            Summary  \
# 0     7.9       80.0  As a new threat to the galaxy rises Rey a dese...
# 1     8.4       78.0  After the devastating events of Avengers: Infi...
# 2     7.8       83.0  A paraplegic Marine dispatched to the moon Pan...
# 3     7.3       88.0  T'Challa heir to the hidden but advanced kingd...
# 4     8.4       68.0  The Avengers and their allies must be willing ...
#
#     Gross       Director1  Director2              Actor1              Actor2  \
# 0  936.66     J.J. Abrams        NaN       Daisy Ridley         John Boyega
# 1  858.37  Anthony Russo   Joe Russo  Robert Downey Jr.         Chris Evans
# 2  760.51   James Cameron        NaN    Sam Worthington         Zoe Saldana
# 3  700.06    Ryan Coogler        NaN   Chadwick Boseman   Michael B. Jordan
# 4  678.82  Anthony Russo   Joe Russo  Robert Downey Jr.     Chris Hemsworth
#
#               Actor3              Actor4                              Genres  \
# 0       Oscar Isaac     Domhnall Gleeson   ['Action', 'Adventure', 'Sci-Fi']
# 1      Mark Ruffalo      Chris Hemsworth    ['Action', 'Adventure', 'Drama']
# 2  Sigourney Weaver   Michelle Rodriguez  ['Action', 'Adventure', 'Fantasy']
# 3    Lupita Nyong'o         Danai Gurira   ['Action', 'Adventure', 'Sci-Fi']
# 4      Mark Ruffalo          Chris Evans   ['Action', 'Adventure', 'Sci-Fi']
#
#    Genre1     Genre2   Genre3  is_animated  is_Adventure  is_Crime  is_Comedy  \
# 0  Action  Adventure   Sci-Fi        False          True     False      False
# 1  Action  Adventure    Drama        False          True     False      False
# 2  Action  Adventure  Fantasy        False          True     False      False
# 3  Action  Adventure   Sci-Fi        False          True     False      False
# 4  Action  Adventure   Sci-Fi        False          True     False      False
#
#    is_Drama  is_Sci-Fi  is_Thriller  is_Horror  is_Fantasy  is_Biography  \
# 0     False       True        False      False       False         False
# 1      True      False        False      False       False         False
# 2     False      False        False      False        True         False
# 3     False       True        False      False       False         False
# 4     False       True        False      False       False         False
#
#    is_Mystery  is_Romance  is_Sport  is_War  is_Western  Years since Release
# 0       False       False     False   False       False                    6
# 1       False       False     False   False       False                    2
# 2       False       False     False   False       False                   12
# 3       False       False     False   False       False                    3
# 4       False       False     False   False       False                    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                1500 non-null   object
#  1   Release              1500 non-null   int64
#  2   Certificate          1359 non-null   object
#  3   Runtime              1500 non-null   int64
#  4   Rating               1500 non-null   float64
#  5   Metascore            1357 non-null   float64
#  6   Summary              1500 non-null   object
#  7   Gross                1500 non-null   float64
#  8   Director1            1500 non-null   object
#  9   Director2            103 non-null    object
#  10  Actor1               1500 non-null   object
#  11  Actor2               1499 non-null   object
#  12  Actor3               1499 non-null   object
#  13  Actor4               1499 non-null   object
#  14  Genres               1500 non-null   object
#  15  Genre1               1500 non-null   object
#  16  Genre2               1494 non-null   object
#  17  Genre3               1363 non-null   object
#  18  is_animated          1500 non-null   bool
#  19  is_Adventure         1500 non-null   bool
#  20  is_Crime             1500 non-null   bool
#  21  is_Comedy            1500 non-null   bool
#  22  is_Drama             1500 non-null   bool
#  23  is_Sci-Fi            1500 non-null   bool
#  24  is_Thriller          1500 non-null   bool
#  25  is_Horror            1500 non-null   bool
#  26  is_Fantasy           1500 non-null   bool
#  27  is_Biography         1500 non-null   bool
#  28  is_Mystery           1500 non-null   bool
#  29  is_Romance           1500 non-null   bool
#  30  is_Sport             1500 non-null   bool
#  31  is_War               1500 non-null   bool
#  32  is_Western           1500 non-null   bool
#  33  Years since Release  1500 non-null   int64
# dtypes: bool(15), float64(3), int64(3), object(13)
# memory usage: 244.8+ KB
